# %%
import pymongo as pm
import pandas as pd
import re

# %%
client = pm.MongoClient(r'mongodb://localhost:27017/')

# %%
db = client["practice_data"]
collection = db["project"]
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'practice_data'), 'project')

# %%
data = list(collection.find())
data
# Out:
# [{'_id': ObjectId('685d0ac96a3a67a0b7e1fd68'),
#   'project_id': 'HCLPJT001',
#   'project_name': 'Digital Banking App',
#   'client': 'ABC Bank',
#   'domain': 'Banking',
#   'location': 'London',
#   'technologies': ['React', 'Node.js', 'MongoDB', 'AWS'],
#   'project_manager': 'Arun Sharma',
#   'start_date': '2024-01-10',
#   'end_date': '2024-11-30',
#   'status': 'In Progress'},
#  {'_id': ObjectId('685d0ac96a3a67a0b7e1fd69'),
#   'project_id': 'HCLPJT002',
#   'project_name': 'SAP Migration',
#   'client': 'Global Manufacturing Ltd',
#   'domain': 'Manufacturing',
#   'location': 'Germany',
#   'technologies': ['SAP S/4HANA', 'ABAP', 'BTP'],
#   'project_manager': 'Priya Mehta',
#   'start_date': '2023-08-01',
#   'end_date': '2024-06-30',
#   'status': 'In Progress'},
#  {'_id': ObjectId('685d0ac96a3a67a0b7e1fd6a'),
#   'project_id': 'HCLPJT003',
#   'project_name': 'E-commerce Revamp',
#   'client': 'TrendyFashions',
#   'domain': 'Retail',
#   'location': 'New York',
# ...

# %%
structured_data = {}
structured_data = pd.DataFrame([structured_data])

for i in data:
    df = pd.DataFrame([i])

    structured_data = pd.concat([structured_data,
                                 df],
                                 ignore_index=True)
structured_data
# Out:
#                          _id project_id                    project_name  \
# 0                        NaN        NaN                             NaN
# 1   685d0ac96a3a67a0b7e1fd68  HCLPJT001             Digital Banking App
# 2   685d0ac96a3a67a0b7e1fd69  HCLPJT002                   SAP Migration
# 3   685d0ac96a3a67a0b7e1fd6a  HCLPJT003               E-commerce Revamp
# 4   685d0ac96a3a67a0b7e1fd6b  HCLPJT004               IoT Smart Devices
# 5   685d0ac96a3a67a0b7e1fd6c  HCLPJT005             Cybersecurity Audit
# 6   685d0ac96a3a67a0b7e1fd6d  HCLPJT006        AI Chatbot for Insurance
# 7   685d0ac96a3a67a0b7e1fd6e  HCLPJT007  Data Lake for Retail Analytics
# 8   685d0ac96a3a67a0b7e1fd6f  HCLPJT008        Legacy App Modernization
# 9   685d0ac96a3a67a0b7e1fd70  HCLPJT009         Cloud Cost Optimization
# 10  685d0ac96a3a67a0b7e1fd71  HCLPJT010        Employee Portal Redesign
#
#                       client          domain       location  \
# ...

# %%
structured_data = pd.DataFrame(data)
structured_data
# Out:
#                         _id project_id                    project_name  \
# 0  685d0ac96a3a67a0b7e1fd68  HCLPJT001             Digital Banking App
# 1  685d0ac96a3a67a0b7e1fd69  HCLPJT002                   SAP Migration
# 2  685d0ac96a3a67a0b7e1fd6a  HCLPJT003               E-commerce Revamp
# 3  685d0ac96a3a67a0b7e1fd6b  HCLPJT004               IoT Smart Devices
# 4  685d0ac96a3a67a0b7e1fd6c  HCLPJT005             Cybersecurity Audit
# 5  685d0ac96a3a67a0b7e1fd6d  HCLPJT006        AI Chatbot for Insurance
# 6  685d0ac96a3a67a0b7e1fd6e  HCLPJT007  Data Lake for Retail Analytics
# 7  685d0ac96a3a67a0b7e1fd6f  HCLPJT008        Legacy App Modernization
# 8  685d0ac96a3a67a0b7e1fd70  HCLPJT009         Cloud Cost Optimization
# 9  685d0ac96a3a67a0b7e1fd71  HCLPJT010        Employee Portal Redesign
#
#                      client          domain       location  \
# 0                  ABC Bank         Banking         London
# 1  Global Manufacturing Ltd   Manufacturing        Germany
# ...

# %%
structured_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              10 non-null     object
#  1   project_id       10 non-null     object
#  2   project_name     10 non-null     object
#  3   client           10 non-null     object
#  4   domain           10 non-null     object
#  5   location         10 non-null     object
#  6   technologies     10 non-null     object
#  7   project_manager  10 non-null     object
#  8   start_date       10 non-null     object
#  9   end_date         10 non-null     object
#  10  status           10 non-null     object
# dtypes: object(11)
# memory usage: 1012.0+ bytes

# %%
structured_data['start_date'] = pd.to_datetime(structured_data['start_date'])
structured_data['end_date'] = pd.to_datetime(structured_data['end_date'])

# %%
structured_data['technologies']
# Out:
# 0             'React', 'Node.js', 'MongoDB', 'AWS'
# 1                     'SAP S/4HANA', 'ABAP', 'BTP'
# 2            'Angular', 'Spring Boot', 'Oracle DB'
# 3      'Python', 'AWS IoT', 'MQTT', 'Raspberry Pi'
# 4              'Splunk', 'Wireshark', 'Kali Linux'
# 5    'Python', 'Dialogflow', 'OpenAI API', 'Flask'
# 6       'Azure Data Lake', 'PySpark', 'Databricks'
# 7     'Java', 'Kubernetes', 'Docker', 'PostgreSQL'
# 8      'Terraform', 'AWS Cost Explorer', 'Ansible'
# 9                    'Next.js', 'GraphQL', 'MySQL'
# Name: technologies, dtype: object

# %%
structured_data['technologies'] = structured_data['technologies'].astype(str).str.replace(r'[\[\]]','', regex=True)

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              10 non-null     object
#  1   project_id       10 non-null     object
#  2   project_name     10 non-null     object
#  3   client           10 non-null     object
#  4   domain           10 non-null     object
#  5   location         10 non-null     object
#  6   technologies     10 non-null     object
#  7   project_manager  10 non-null     object
#  8   start_date       10 non-null     object
#  9   end_date         10 non-null     object
#  10  status           10 non-null     object
# dtypes: object(11)
# memory usage: 1012.0+ bytes

# %%
import pandas as pd
import configparser as cp
from sqlalchemy import create_engine
import urllib

def connect(data, Table_name):
    # Read config file
    config = cp.ConfigParser()
    config.read(r'C:\Users\mysur\OneDrive\Desktop\python_tutorial\venv1\config.config')

    DRIVER = config['ssms']['DRIVER']
    SERVER = config['ssms']['SERVER']
    DATABASE = config['ssms']['DATABASE']
    UID = config['ssms']['UID']
    PWD = config['ssms']['PWD']

    # Create connection string for SQLAlchemy
    connection_string = (
        f'DRIVER={DRIVER};'
        f'SERVER={SERVER};'
        f'DATABASE={DATABASE};'
        f'UID={UID};'
        f'PWD={PWD}'
    )

    # URL encode the connection string
    params = urllib.parse.quote_plus(connection_string)

    # Create SQLAlchemy engine
    engine = create_engine(f"mssql+pyodbc:///?odbc_connect={params}")

    # Load data to SQL Server
    data.to_sql(
        name=Table_name,
        con=engine,
        index=False,
        if_exists='replace'
    )
df = {'a':1,
      'b':2}

df = pd.DataFrame([df])
connect(df, 'xyz')

# %%
structured_data['_id'] = structured_data['_id'].astype(str)
